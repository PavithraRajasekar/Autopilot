# %% [markdown]
# Install libraries

# %%
#@title Install libraries
import torch
print(torch.__version__)
# !pip install datasets transformers[sentencepiece]
# !apt install git-lfs

# %% [markdown]
# Download the model

# %%
import torch
from transformers import pipeline

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
pipe = pipeline(
    "text-generation", model="mimicheng/codeparrot-ds-sample-2ep-14apr")
# Out:
# Downloading:   0%|          | 0.00/898 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/632M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/276 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/771k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %% [markdown]
# Input some prompt in a doc string

# %%
txt = """\
# create some data
x = np.random.randn(100)
y = np.random.randn(100)

# create scatter plot with x, y
"""
print(pipe(txt, num_return_sequences=1)[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # create some data
# x = np.random.randn(100)
# y = np.random.randn(100)
#
# # create scatter plot with x, y
# fig, ax = plt.subplots()
# ax.scatter(

# %%
txt = """\
# dataframe with profession, income and name
df = pd.DataFrame({'profession': x, 'income':y, 'name': z})

# calculate the mean income per profession
"""
print(pipe(txt, num_return_sequences=1)[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # dataframe with profession, income and name
# df = pd.DataFrame({'profession': x, 'income':y, 'name': z})
#
# # calculate the mean income per profession
# sns.mean_income

# %%
txt = """\
# create a numpy array of size 5
x = np.array([1,2,3,4,5])

# create a numpy array of size 10
"""
print(pipe(txt, num_return_sequences=1)[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# # create a numpy array of size 5
# x = np.array([1,2,3,4,5])
#
# # create a numpy array of size 10
# y = np.array([1,2,3,4,
